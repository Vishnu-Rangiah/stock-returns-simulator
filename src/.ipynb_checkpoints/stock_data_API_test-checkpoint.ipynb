# %%
import requests 
import pandas as pd
from datetime import datetime
import numpy as np

SYMBOL = ("VOO")
url = "https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY_ADJUSTED&symbol="+SYMBOL+"&apikey=L14KLEPQ80F26X4M"
response = requests.get(url)

# %%
output = response.json()
stock_dates_dict = output["Monthly Adjusted Time Series"]

# %%
stock_dates_dict
# Out:
# {'2022-03-09': {'1. open': '400.0100',
#   '2. high': '405.5400',
#   '3. low': '381.6400',
#   '4. close': '392.9000',
#   '5. adjusted close': '392.9000',
#   '6. volume': '55925955',
#   '7. dividend amount': '0.0000'},
#  '2022-02-28': {'1. open': '414.3400',
#   '2. high': '421.1800',
#   '3. low': '377.5000',
#   '4. close': '401.3600',
#   '5. adjusted close': '401.3600',
#   '6. volume': '178123502',
#   '7. dividend amount': '0.0000'},
#  '2022-01-31': {'1. open': '437.9300',
#   '2. high': '441.2600',
#   '3. low': '386.8400',
#   '4. close': '413.6900',
#   '5. adjusted close': '413.6900',
#   '6. volume': '209277200',
#   '7. dividend amount': '0.0000'},
#  '2021-12-31': {'1. open': '424.4700',
#   '2. high': '440.3600',
#   '3. low': '412.7700',
#   '4. close': '436.5700',
#   '5. adjusted close': '436.5700',
#   '6. volume': '142126854',
#   '7. dividend amount': '1.5329'},
#  '2021-11-30': {'1. open': '423.1900',
#   '2. high': '435.4100',
#   '3. low': '418.6300',
#   '4. close': '419.0600',
#   '5. adjusted close': '417.5564',
#   '6. volume': '100053866',
#   '7. dividend amount': '0.0000'},
#  '2021-10-29': {'1. open': '396.2262',
#   '2. high': '422.5150',
#   '3. low': '391.9600',
#   '4. close': '422.1600',
#   '5. adjusted close': '420.6453',
#   '6. volume': '93894175',
#   '7. dividend amount': '0.0000'},
#  '2021-09-30': {'1. open': '416.0500',
#   '2. high': '417.4400',
#   '3. low': '394.3400',
#   '4. close': '394.4000',
#   '5. adjusted close': '392.9849',
#   '6. volume': '103248307',
#   '7. dividend amount': '1.3084'},
#  '2021-08-31': {'1. open': '404.7800',
#   '2. high': '416.5600',
#   '3. low': '400.9200',
#   '4. close': '415.0500',
#   '5. adjusted close': '412.2106',
#   '6. volume': '81058621',
#   '7. dividend amount': '0.0000'},
#  '2021-07-30': {'1. open': '394.3000',
#   '2. high': '406.1300',
#   '3. low': '387.9300',
#   '4. close': '403.1500',
#   '5. adjusted close': '400.3920',
#   '6. volume': '87866050',
#   '7. dividend amount': '0.0000'},
#  '2021-06-30': {'1. open': '388.5000',
#   '2. high': '394.4500',
#   '3. low': '382.5200',
#   '4. close': '393.5200',
#   '5. adjusted close': '390.8279',
#   '6. volume': '68852165',
#   '7. dividend amount': '1.3329'},
#  '2021-05-28': {'1. open': '385.5600',
#   '2. high': '388.6800',
#   '3. low': '372.1300',
#   '4. close': '386.1300',
#   '5. adjusted close': '382.1927',
#   '6. volume': '89691613',
#   '7. dividend amount': '0.0000'},
#  '2021-04-30': {'1. open': '366.2000',
#   '2. high': '386.7400',
#   '3. low': '366.0300',
#   '4. close': '383.5700',
#   '5. adjusted close': '379.6588',
#   '6. volume': '77401939',
#   '7. dividend amount': '0.0000'},
#  '2021-03-31': {'1. open': '354.5500',
#   '2. high': '366.0500',
#   '3. low': '341.9150',
#   '4. close': '364.3000',
#   '5. adjusted close': '360.5853',
#   '6. volume': '115909237',
#   '7. dividend amount': '1.2625'},
#  '2021-02-26': {'1. open': '343.6300',
#   '2. high': '362.3700',
#   '3. low': '341.4000',
#   '4. close': '349.5900',
#   '5. adjusted close': '344.8294',
#   '6. volume': '65076646',
#   '7. dividend amount': '0.0000'},
#  '2021-01-29': {'1. open': '345.0200',
#   '2. high': '354.6450',
#   '3. low': '335.3700',
#   '4. close': '340.1800',
#   '5. adjusted close': '335.5475',
#   '6. volume': '67318058',
#   '7. dividend amount': '0.0000'},
#  '2020-12-31': {'1. open': '335.9200',
#   '2. high': '344.3700',
#   '3. low': '333.7700',
#   '4. close': '343.6900',
#   '5. adjusted close': '339.0097',
#   '6. volume': '62049300',
#   '7. dividend amount': '1.3829'},
#  '2020-11-30': {'1. open': '303.3700',
#   '2. high': '335.2000',
#   '3. low': '300.6300',
#   '4. close': '332.6400',
#   '5. adjusted close': '326.7714',
#   '6. volume': '67765492',
#   '7. dividend amount': '0.0000'},
#  '2020-10-30': {'1. open': '310.1600',
#   '2. high': '325.2220',
#   '3. low': '296.3700',
#   '4. close': '299.8200',
#   '5. adjusted close': '294.5304',
#   '6. volume': '62743173',
#   '7. dividend amount': '0.0000'},
#  '2020-09-30': {'1. open': '321.8100',
#   '2. high': '329.6700',
#   '3. low': '295.0400',
#   '4. close': '307.6500',
#   '5. adjusted close': '302.2223',
#   '6. volume': '74318208',
#   '7. dividend amount': '1.3085'},
#  '2020-08-31': {'1. open': '301.6500',
#   '2. high': '322.8300',
#   '3. low': '301.1300',
#   '4. close': '321.0200',
#   '5. adjusted close': '314.0106',
#   '6. volume': '61288229',
#   '7. dividend amount': '0.0000'},
#  '2020-07-31': {'1. open': '284.3700',
#   '2. high': '300.6200',
#   '3. low': '283.9500',
#   '4. close': '300.1000',
#   '5. adjusted close': '293.5474',
#   '6. volume': '74664917',
#   '7. dividend amount': '0.0000'},
#  '2020-06-30': {'1. open': '279.0700',
#   '2. high': '297.3200',
#   '3. low': '272.7700',
#   '4. close': '283.4300',
#   '5. adjusted close': '277.2413',
#   '6. volume': '98428161',
#   '7. dividend amount': '1.4333'},
#  '2020-05-29': {'1. open': '262.1400',
#   '2. high': '282.0400',
#   '3. low': '253.9700',
#   '4. close': '279.7500',
#   '5. adjusted close': '272.2466',
#   '6. volume': '92403670',
#   '7. dividend amount': '0.0000'},
#  '2020-04-30': {'1. open': '227.9200',
#   '2. high': '271.0000',
#   '3. low': '224.1300',
#   '4. close': '267.1000',
#   '5. adjusted close': '259.9359',
#   '6. volume': '148503528',
#   '7. dividend amount': '0.0000'},
#  '2020-03-31': {'1. open': '274.0000',
#   '2. high': '288.3200',
#   '3. low': '200.5500',
#   '4. close': '236.8200',
#   '5. adjusted close': '230.4680',
#   '6. volume': '280853662',
#   '7. dividend amount': '1.1780'},
#  '2020-02-28': {'1. open': '297.1200',
#   '2. high': '311.5900',
#   '3. low': '262.2500',
#   '4. close': '271.7400',
#   '5. adjusted close': '263.2758',
#   '6. volume': '99491729',
#   '7. dividend amount': '0.0000'},
#  '2020-01-31': {'1. open': '297.2900',
#   '2. high': '305.9200',
#   '3. low': '294.3500',
#   '4. close': '295.6900',
#   '5. adjusted close': '286.4798',
#   '6. volume': '66578377',
#   '7. dividend amount': '0.0000'},
#  '2019-12-31': {'1. open': '289.0300',
#   '2. high': '297.5100',
#   '3. low': '282.1000',
#   '4. close': '295.8000',
#   '5. adjusted close': '286.5864',
#   '6. volume': '56493484',
#   '7. dividend amount': '1.4290'},
#  '2019-11-29': {'1. open': '280.0500',
#   '2. high': '289.7800',
#   '3. low': '279.9100',
#   '4. close': '288.6500',
#   '5. adjusted close': '278.3117',
#   '6. volume': '43805096',
#   '7. dividend amount': '0.0000'},
#  '2019-10-31': {'1. open': '273.4400',
#   '2. high': '279.6900',
#   '3. low': '261.5900',
#   '4. close': '278.5500',
#   '5. adjusted close': '268.5734',
#   '6. volume': '52914243',
#   '7. dividend amount': '0.0000'},
#  '2019-09-30': {'1. open': '266.8300',
#   '2. high': '277.9800',
#   '3. low': '265.6800',
#   '4. close': '272.6000',
#   '5. adjusted close': '262.8365',
#   '6. volume': '45908331',
#   '7. dividend amount': '1.3014'},
#  '2019-08-30': {'1. open': '273.2800',
#   '2. high': '276.2800',
#   '3. low': '258.7000',
#   '4. close': '268.6000',
#   '5. adjusted close': '257.7501',
#   '6. volume': '76712465',
#   '7. dividend amount': '0.0000'},
#  '2019-07-31': {'1. open': '272.4600',
#   '2. high': '277.5500',
#   '3. low': '270.3000',
#   '4. close': '273.0800',
#   '5. adjusted close': '262.0492',
#   '6. volume': '55504714',
#   '7. dividend amount': '0.0000'},
#  '2019-06-28': {'1. open': '252.8300',
#   '2. high': '272.7900',
#   '3. low': '250.7700',
#   '4. close': '269.1500',
#   '5. adjusted close': '258.2779',
#   '6. volume': '48687588',
#   '7. dividend amount': '1.3859'},
#  '2019-05-31': {'1. open': '270.6800',
#   '2. high': '270.8700',
#   '3. low': '252.7700',
#   '4. close': '252.8700',
#   '5. adjusted close': '241.4056',
#   '6. volume': '72319825',
#   '7. dividend amount': '0.0000'},
#  '2019-04-30': {'1. open': '261.4600',
#   '2. high': '270.4100',
#   '3. low': '261.1900',
#   '4. close': '270.0100',
#   '5. adjusted close': '257.7685',
#   '6. volume': '41356493',
#   '7. dividend amount': '0.0000'},
#  '2019-03-29': {'1. open': '257.8100',
#   '2. high': '262.5900',
#   '3. low': '250.3400',
#   '4. close': '259.5400',
#   '5. adjusted close': '247.7732',
#   '6. volume': '62971771',
#   '7. dividend amount': '1.4551'},
#  '2019-02-28': {'1. open': '248.3100',
#   '2. high': '258.6100',
#   '3. low': '246.2000',
#   '4. close': '256.0700',
#   '5. adjusted close': '243.1074',
#   '6. volume': '57657355',
#   '7. dividend amount': '0.0000'},
#  '2019-01-31': {'1. open': '226.1800',
#   '2. high': '248.5300',
#   '3. low': '223.9700',
#   '4. close': '248.0100',
#   '5. adjusted close': '235.4554',
#   '6. volume': '81248101',
#   '7. dividend amount': '0.0000'},
#  '2018-12-31': {'1. open': '257.6500',
#   '2. high': '257.7400',
#   '3. low': '214.8300',
#   '4. close': '229.8100',
#   '5. adjusted close': '218.1767',
#   '6. volume': '128542134',
#   '7. dividend amount': '1.2890'},
#  '2018-11-30': {'1. open': '249.6300',
#   '2. high': '258.4400',
#   '3. low': '241.7300',
#   '4. close': '253.4800',
#   '5. adjusted close': '239.3258',
#   '6. volume': '61115981',
#   '7. dividend amount': '0.0000'},
#  '2018-10-31': {'1. open': '268.4600',
#   '2. high': '269.4700',
#   '3. low': '238.7900',
#   '4. close': '248.7900',
#   '5. adjusted close': '234.8977',
#   '6. volume': '91440664',
#   '7. dividend amount': '0.0000'},
#  '2018-09-28': {'1. open': '266.3500',
#   '2. high': '270.6700',
#   '3. low': '263.4500',
#   '4. close': '267.0500',
#   '5. adjusted close': '252.1381',
#   '6. volume': '48733249',
#   '7. dividend amount': '1.2067'},
#  '2018-08-31': {'1. open': '258.6400',
#   '2. high': '268.0500',
#   '3. low': '256.4800',
#   '4. close': '266.7200',
#   '5. adjusted close': '250.6907',
#   '6. volume': '49557399',
#   '7. dividend amount': '0.0000'},
#  '2018-07-31': {'1. open': '247.5600',
#   '2. high': '261.2500',
#   '3. low': '247.3200',
#   '4. close': '258.4000',
#   '5. adjusted close': '242.8707',
#   '6. volume': '45590887',
#   '7. dividend amount': '0.0000'},
#  '2018-06-29': {'1. open': '250.2300',
#   '2. high': '256.7700',
#   '3. low': '246.6300',
#   '4. close': '249.5100',
#   '5. adjusted close': '234.5150',
#   '6. volume': '54661028',
#   '7. dividend amount': '1.1573'},
#  '2018-05-31': {'1. open': '242.4500',
#   '2. high': '251.9400',
#   '3. low': '237.9200',
#   '4. close': '248.7900',
#   '5. adjusted close': '232.7560',
#   '6. volume': '43982726',
#   '7. dividend amount': '0.0000'},
#  '2018-04-30': {'1. open': '241.1900',
#   '2. high': '249.2200',
#   '3. low': '233.9200',
#   '4. close': '242.9200',
#   '5. adjusted close': '227.2643',
#   '6. volume': '57321176',
#   '7. dividend amount': '0.0000'},
#  '2018-03-29': {'1. open': '249.5300',
#   '2. high': '257.7100',
#   '3. low': '237.5300',
#   '4. close': '242.0800',
#   '5. adjusted close': '226.4784',
#   '6. volume': '63874271',
#   '7. dividend amount': '1.0837'},
#  '2018-02-28': {'1. open': '258.2900',
#   '2. high': '260.1200',
#   '3. low': '232.4200',
#   '4. close': '249.3400',
#   '5. adjusted close': '232.2371',
#   '6. volume': '88662613',
#   '7. dividend amount': '0.0000'},
#  '2018-01-31': {'1. open': '246.1500',
#   '2. high': '263.3700',
#   '3. low': '245.7400',
#   '4. close': '258.9900',
#   '5. adjusted close': '241.2251',
#   '6. volume': '63556077',
#   '7. dividend amount': '0.0000'},
#  '2017-12-29': {'1. open': '243.2500',
#   '2. high': '248.0100',
#   '3. low': '239.5200',
#   '4. close': '245.2900',
#   '5. adjusted close': '228.4649',
#   '6. volume': '44188882',
#   '7. dividend amount': '1.1839'},
#  '2017-11-30': {'1. open': '237.0300',
#   '2. high': '244.4000',
#   '3. low': '234.8200',
#   '4. close': '243.3500',
#   '5. adjusted close': '225.5703',
#   '6. volume': '43297760',
#   '7. dividend amount': '0.0000'},
#  '2017-10-31': {'1. open': '231.0000',
#   '2. high': '236.8800',
#   '3. low': '230.9100',
#   '4. close': '236.1300',
#   '5. adjusted close': '218.8778',
#   '6. volume': '33049401',
#   '7. dividend amount': '0.0000'},
#  '2017-09-29': {'1. open': '227.7600',
#   '2. high': '230.9000',
#   '3. low': '224.9800',
#   '4. close': '230.7600',
#   '5. adjusted close': '213.9002',
#   '6. volume': '33379043',
#   '7. dividend amount': '1.1760'},
#  '2017-08-31': {'1. open': '227.3000',
#   '2. high': '228.6200',
#   '3. low': '222.1200',
#   '4. close': '227.3000',
#   '5. adjusted close': '209.6199',
#   '6. volume': '37614775',
#   '7. dividend amount': '0.0000'},
#  '2017-07-31': {'1. open': '223.0900',
#   '2. high': '227.7800',
#   '3. low': '220.7200',
#   '4. close': '226.6400',
#   '5. adjusted close': '209.0112',
#   '6. volume': '37713634',
#   '7. dividend amount': '0.0000'},
#  '2017-06-30': {'1. open': '222.1400',
#   '2. high': '225.7650',
#   '3. low': '220.4191',
#   '4. close': '222.0600',
#   '5. adjusted close': '204.7875',
#   '6. volume': '43548871',
#   '7. dividend amount': '1.0100'},
#  '2017-05-31': {'1. open': '219.1600',
#   '2. high': '222.2400',
#   '3. low': '216.1301',
#   '4. close': '221.6700',
#   '5. adjusted close': '203.5076',
#   '6. volume': '40645231',
#   '7. dividend amount': '0.0000'},
#  '2017-04-28': {'1. open': '216.5100',
#   '2. high': '219.8979',
#   '3. low': '213.4700',
#   '4. close': '218.6000',
#   '5. adjusted close': '200.6891',
#   '6. volume': '39163153',
#   '7. dividend amount': '0.0000'},
#  '2017-03-31': {'1. open': '218.9000',
#   '2. high': '220.6600',
#   '3. low': '212.6200',
#   '4. close': '216.3500',
#   '5. adjusted close': '198.6235',
#   '6. volume': '47635680',
#   '7. dividend amount': '0.9980'},
#  '2017-02-28': {'1. open': '209.6200',
#   '2. high': '217.8956',
#   '3. low': '208.2300',
#   '4. close': '217.0700',
#   '5. adjusted close': '198.3638',
#   '6. volume': '35461170',
#   '7. dividend amount': '0.0000'},
#  '2017-01-31': {'1. open': '206.6800',
#   '2. high': '210.9000',
#   '3. low': '205.5600',
#   '4. close': '208.9700',
#   '5. adjusted close': '190.9618',
#   '6. volume': '57281277',
#   '7. dividend amount': '0.0000'},
#  '2016-12-30': {'1. open': '202.6800',
#   '2. high': '209.7000',
#   '3. low': '201.2400',
#   '4. close': '205.3100',
#   '5. adjusted close': '187.6172',
#   '6. volume': '52288794',
#   '7. dividend amount': '1.2960'},
#  '2016-11-30': {'1. open': '195.5200',
#   '2. high': '203.6920',
#   '3. low': '191.3200',
#   '4. close': '202.4000',
#   '5. adjusted close': '183.8073',
#   '6. volume': '52717518',
#   '7. dividend amount': '0.0000'},
#  '2016-10-31': {'1. open': '198.1800',
#   '2. high': '198.9500',
#   '3. low': '193.9200',
#   '4. close': '195.1300',
#   '5. adjusted close': '177.2051',
#   '6. volume': '33928914',
#   '7. dividend amount': '0.0000'},
#  '2016-09-30': {'1. open': '199.5000',
#   '2. high': '201.1500',
#   '3. low': '194.1200',
#   '4. close': '198.6900',
#   '5. adjusted close': '180.4381',
#   '6. volume': '44972180',
#   '7. dividend amount': '0.8830'},
#  '2016-08-31': {'1. open': '199.3300',
#   '2. high': '201.5100',
#   '3. low': '196.8800',
#   '4. close': '199.5200',
#   '5. adjusted close': '180.3741',
#   '6. volume': '43950860',
#   '7. dividend amount': '0.0000'},
#  '2016-07-29': {'1. open': '192.0900',
#   '2. high': '199.6000',
#   '3. low': '189.9700',
#   '4. close': '199.2800',
#   '5. adjusted close': '180.1572',
#   '6. volume': '41943696',
#   '7. dividend amount': '0.0000'},
#  '2016-06-30': {'1. open': '191.8800',
#   '2. high': '194.9500',
#   '3. low': '182.2700',
#   '4. close': '192.2000',
#   '5. adjusted close': '173.7566',
#   '6. volume': '61820387',
#   '7. dividend amount': '0.9530'},
#  '2016-05-31': {'1. open': '189.8100',
#   '2. high': '193.2700',
#   '3. low': '185.9700',
#   '4. close': '192.5400',
#   '5. adjusted close': '173.2008',
#   '6. volume': '38143184',
#   '7. dividend amount': '0.0000'},
#  '2016-04-29': {'1. open': '187.4000',
#   '2. high': '193.4300',
#   '3. low': '186.2600',
#   '4. close': '189.2200',
#   '5. adjusted close': '170.2143',
#   '6. volume': '42411514',
#   '7. dividend amount': '0.0000'},
#  '2016-03-31': {'1. open': '178.8400',
#   '2. high': '189.7200',
#   '3. low': '178.3300',
#   '4. close': '188.5600',
#   '5. adjusted close': '169.6206',
#   '6. volume': '50006524',
#   '7. dividend amount': '1.0060'},
#  '2016-02-29': {'1. open': '176.6100',
#   '2. high': '180.3600',
#   '3. low': '166.0500',
#   '4. close': '177.3800',
#   '5. adjusted close': '158.7130',
#   '6. volume': '54703609',
#   '7. dividend amount': '0.0000'},
#  '2016-01-29': {'1. open': '183.7700',
#   '2. high': '185.1150',
#   '3. low': '165.9600',
#   '4. close': '177.7500',
#   '5. adjusted close': '159.0441',
#   '6. volume': '82600328',
#   '7. dividend amount': '0.0000'},
#  '2015-12-31': {'1. open': '192.0500',
#   '2. high': '193.4462',
#   '3. low': '183.3100',
#   '4. close': '186.9300',
#   '5. adjusted close': '167.2580',
#   '6. volume': '62484546',
#   '7. dividend amount': '1.0920'},
#  '2015-11-30': {'1. open': '190.9800',
#   '2. high': '194.0600',
#   '3. low': '185.3600',
#   '4. close': '191.3700',
#   '5. adjusted close': '170.2256',
#   '6. volume': '38628911',
#   '7. dividend amount': '0.0000'},
#  '2015-10-30': {'1. open': '175.9700',
#   '2. high': '192.0000',
#   '3. low': '173.3500',
#   '4. close': '190.5600',
#   '5. adjusted close': '169.5051',
#   '6. volume': '38175215',
#   '7. dividend amount': '0.0000'},
#  '2015-09-30': {'1. open': '177.1100',
#   '2. high': '185.9900',
#   '3. low': '171.3601',
#   '4. close': '175.7100',
#   '5. adjusted close': '156.2959',
#   '6. volume': '57336788',
#   '7. dividend amount': '0.9530'},
#  '2015-08-31': {'1. open': '193.0000',
#   '2. high': '193.7500',
#   '3. low': '168.0800',
#   '4. close': '181.1100',
#   '5. adjusted close': '160.2512',
#   '6. volume': '75865612',
#   '7. dividend amount': '0.0000'},
#  '2015-07-31': {'1. open': '190.6500',
#   '2. high': '195.4600',
#   '3. low': '187.1900',
#   '4. close': '192.9500',
#   '5. adjusted close': '170.7276',
#   '6. volume': '35082721',
#   '7. dividend amount': '0.0000'},
#  '2015-06-30': {'1. open': '194.2300',
#   '2. high': '195.5300',
#   '3. low': '188.2400',
#   '4. close': '188.8400',
#   '5. adjusted close': '167.0910',
#   '6. volume': '32509149',
#   '7. dividend amount': '0.9020'},
#  '2015-05-29': {'1. open': '191.9600',
#   '2. high': '195.9500',
#   '3. low': '189.5300',
#   '4. close': '193.4900',
#   '5. adjusted close': '170.4142',
#   '6. volume': '25759190',
#   '7. dividend amount': '0.0000'},
#  '2015-04-30': {'1. open': '189.1700',
#   '2. high': '194.7400',
#   '3. low': '187.4700',
#   '4. close': '191.1000',
#   '5. adjusted close': '168.3092',
#   '6. volume': '30250181',
#   '7. dividend amount': '0.0000'},
#  '2015-03-31': {'1. open': '193.3100',
#   '2. high': '194.4700',
#   '3. low': '187.1500',
#   '4. close': '189.2000',
#   '5. adjusted close': '166.6358',
#   '6. volume': '35630044',
#   '7. dividend amount': '0.9840'},
#  '2015-02-27': {'1. open': '183.5000',
#   '2. high': '194.6500',
#   '3. low': '181.4700',
#   '4. close': '193.2000',
#   '5. adjusted close': '169.2935',
#   '6. volume': '30736282',
#   '7. dividend amount': '0.0000'},
#  '2015-01-30': {'1. open': '189.2900',
#   '2. high': '189.7200',
#   '3. low': '182.0868',
#   '4. close': '182.9900',
#   '5. adjusted close': '160.3469',
#   '6. volume': '51626988',
#   '7. dividend amount': '0.0000'},
#  '2014-12-31': {'1. open': '189.2900',
#   '2. high': '191.6340',
#   '3. low': '181.4400',
#   '4. close': '188.4000',
#   '5. adjusted close': '165.0874',
#   '6. volume': '49040173',
#   '7. dividend amount': '1.0260'},
#  '2014-11-28': {'1. open': '185.2000',
#   '2. high': '190.6300',
#   '3. low': '183.4500',
#   '4. close': '190.0300',
#   '5. adjusted close': '165.6145',
#   '6. volume': '27698042',
#   '7. dividend amount': '0.0000'},
#  '2014-10-31': {'1. open': '180.3400',
#   '2. high': '185.0500',
#   '3. low': '166.8500',
#   '4. close': '184.9300',
#   '5. adjusted close': '161.1698',
#   '6. volume': '47155466',
#   '7. dividend amount': '0.0000'},
#  '2014-09-30': {'1. open': '184.3000',
#   '2. high': '185.8400',
#   '3. low': '179.7700',
#   '4. close': '180.5900',
#   '5. adjusted close': '157.3874',
#   '6. volume': '17064009',
#   '7. dividend amount': '0.8760'},
#  '2014-08-29': {'1. open': '176.5200',
#   '2. high': '184.1700',
#   '3. low': '174.7000',
#   '4. close': '183.9900',
#   '5. adjusted close': '159.5848',
#   '6. volume': '23864300',
#   '7. dividend amount': '0.0000'},
#  '2014-07-31': {'1. open': '179.8800',
#   '2. high': '182.5000',
#   '3. low': '176.9600',
#   '4. close': '176.9600',
#   '5. adjusted close': '153.4873',
#   '6. volume': '18901400',
#   '7. dividend amount': '0.0000'},
#  '2014-06-30': {'1. open': '176.8300',
#   '2. high': '180.5700',
#   '3. low': '175.9440',
#   '4. close': '179.4300',
#   '5. adjusted close': '155.6297',
#   '6. volume': '19356700',
#   '7. dividend amount': '0.8090'},
#  '2014-05-30': {'1. open': '172.5000',
#   '2. high': '176.6900',
#   '3. low': '170.4400',
#   '4. close': '176.5500',
#   '5. adjusted close': '152.4449',
#   '6. volume': '20604100',
#   '7. dividend amount': '0.0000'},
#  '2014-04-30': {'1. open': '171.8700',
#   '2. high': '173.8200',
#   '3. low': '166.1121',
#   '4. close': '172.5900',
#   '5. adjusted close': '149.0255',
#   '6. volume': '27491700',
#   '7. dividend amount': '0.0000'},
#  '2014-03-31': {'1. open': '169.1900',
#   '2. high': '173.1890',
#   '3. low': '168.3800',
#   '4. close': '171.3500',
#   '5. adjusted close': '147.9548',
#   '6. volume': '24621000',
#   '7. dividend amount': '0.7790'},
#  '2014-02-28': {'1. open': '163.0200',
#   '2. high': '171.4690',
#   '3. low': '159.1800',
#   '4. close': '170.6300',
#   '5. adjusted close': '146.6608',
#   '6. volume': '24164200',
#   '7. dividend amount': '0.0000'},
#  '2014-01-31': {'1. open': '168.5300',
#   '2. high': '169.4300',
#   '3. low': '162.0700',
#   '4. close': '163.1800',
#   '5. adjusted close': '140.2573',
#   '6. volume': '29636000',
#   '7. dividend amount': '0.0000'},
#  '2013-12-31': {'1. open': '165.9500',
#   '2. high': '169.2300',
#   '3. low': '162.0100',
#   '4. close': '169.1500',
#   '5. adjusted close': '145.3887',
#   '6. volume': '31082700',
#   '7. dividend amount': '0.9140'},
#  '2013-11-29': {'1. open': '161.2800',
#   '2. high': '166.5100',
#   '3. low': '160.1000',
#   '4. close': '165.7000',
#   '5. adjusted close': '141.6511',
#   '6. volume': '26113000',
#   '7. dividend amount': '0.0000'},
#  '2013-10-31': {'1. open': '77.0200',
#   '2. high': '162.6200',
#   '3. low': '75.3600',
#   '4. close': '160.8800',
#   '5. adjusted close': '137.5306',
#   '6. volume': '59089200',
#   '7. dividend amount': '0.0000'},
#  '2013-09-30': {'1. open': '75.6600',
#   '2. high': '79.5200',
#   '3. low': '74.9700',
#   '4. close': '77.0000',
#   '5. adjusted close': '131.6491',
#   '6. volume': '46964600',
#   '7. dividend amount': '0.3930'},
#  '2013-08-30': {'1. open': '77.8400',
#   '2. high': '78.3090',
#   '3. low': '74.6700',
#   '4. close': '74.8500',
#   '5. adjusted close': '127.3306',
#   '6. volume': '29719000',
#   '7. dividend amount': '0.0000'},
#  '2013-07-31': {'1. open': '73.8699',
#   '2. high': '77.8068',
#   '3. low': '73.3800',
#   '4. close': '77.2300',
#   '5. adjusted close': '131.3793',
#   '6. volume': '33382600',
#   '7. dividend amount': '0.0000'},
#  '2013-06-28': {'1. open': '75.0300',
#   '2. high': '76.0000',
#   '3. low': '71.3300',
#   '4. close': '73.3400',
#   '5. adjusted close': '124.7619',
#   '6. volume': '52017600',
#   '7. dividend amount': '0.3690'},
#  '2013-05-31': {'1. open': '72.9600',
#   '2. high': '77.4260',
#   '3. low': '72.3900',
#   '4. close': '74.8400',
#   '5. adjusted close': '126.6636',
#   '6. volume': '28131200',
#   '7. dividend amount': '0.0000'},
#  '2013-04-30': {'1. open': '71.7000',
#   '2. high': '73.1400',
#   '3. low': '70.2900',
#   '4. close': '73.1400',
#   '5. adjusted close': '123.7864',
#   '6. volume': '37696800',
#   '7. dividend amount': '0.0000'},
#  '2013-03-28': {'1. open': '69.1600',
#   '2. high': '71.8100',
#   '3. low': '68.8700',
#   '4. close': '71.6400',
#   '5. adjusted close': '121.2478',
#   '6. volume': '29218000',
#   '7. dividend amount': '0.3350'},
#  '2013-02-28': {'1. open': '68.9900',
#   '2. high': '70.1800',
#   '3. low': '68.1100',
#   '4. close': '69.4700',
#   '5. adjusted close': '117.0244',
#   '6. volume': '33837600',
#   '7. dividend amount': '0.0000'},
#  '2013-01-31': {'1. open': '66.4700',
#   '2. high': '69.1000',
#   '3. low': '66.2800',
#   '4. close': '68.5600',
#   '5. adjusted close': '115.4915',
#   '6. volume': '37857200',
#   '7. dividend amount': '0.0000'},
#  '2012-12-31': {'1. open': '65.3700',
#   '2. high': '66.6600',
#   '3. low': '63.9000',
#   '4. close': '65.1900',
#   '5. adjusted close': '109.8146',
#   '6. volume': '23459000',
#   '7. dividend amount': '0.4700'},
#  '2012-11-30': {'1. open': '64.8600',
#   '2. high': '65.7900',
#   '3. low': '61.6900',
#   '4. close': '65.0000',
#   '5. adjusted close': '108.7107',
#   '6. volume': '18781000',
#   '7. dividend amount': '0.0000'},
#  '2012-10-31': {'1. open': '66.1500',
#   '2. high': '67.3600',
#   '3. low': '64.2700',
#   '4. close': '64.6300',
#   '5. adjusted close': '108.0919',
#   '6. volume': '15642200',
#   '7. dividend amount': '0.0000'},
#  '2012-09-28': {'1. open': '64.5700',
#   '2. high': '67.7900',
#   '3. low': '64.1200',
#   '4. close': '65.9200',
#   '5. adjusted close': '110.2494',
#   '6. volume': '16113400',
#   '7. dividend amount': '0.3430'},
#  '2012-08-31': {'1. open': '63.4400',
#   '2. high': '65.4700',
#   '3. low': '62.0400',
#   '4. close': '64.6100',
#   '5. adjusted close': '107.5054',
#   '6. volume': '16474800',
#   '7. dividend amount': '0.0000'},
#  '2012-07-31': {'1. open': '62.4500',
#   '2. high': '63.7300',
#   '3. low': '60.6600',
#   '4. close': '63.0300',
#   '5. adjusted close': '104.8764',
#   '6. volume': '16965000',
#   '7. dividend amount': '0.0000'},
#  '2012-06-29': {'1. open': '59.1700',
#   '2. high': '62.6500',
#   '3. low': '58.1715',
#   '4. close': '62.2800',
#   '5. adjusted close': '103.6285',
#   '6. volume': '15118800',
#   '7. dividend amount': '0.3200'},
#  '2012-05-31': {'1. open': '63.9800',
#   '2. high': '64.8000',
#   '3. low': '59.2766',
#   '4. close': '60.1200',
#   '5. adjusted close': '99.5045',
#   '6. volume': '20885400',
#   '7. dividend amount': '0.0000'},
#  '2012-04-30': {'1. open': '64.3700',
#   '2. high': '65.0600',
#   '3. low': '62.1100',
#   '4. close': '63.9600',
#   '5. adjusted close': '105.8600',
#   '6. volume': '19240200',
#   '7. dividend amount': '0.0000'},
#  '2012-03-30': {'1. open': '62.8200',
#   '2. high': '64.9199',
#   '3. low': '61.4500',
#   '4. close': '64.3700',
#   '5. adjusted close': '106.5386',
#   '6. volume': '20129000',
#   '7. dividend amount': '0.2850'},
#  '2012-02-29': {'1. open': '60.5000',
#   '2. high': '63.1976',
#   '3. low': '60.4300',
#   '4. close': '62.5900',
#   '5. adjusted close': '103.1387',
#   '6. volume': '10331200',
#   '7. dividend amount': '0.0000'},
#  '2012-01-31': {'1. open': '58.4500',
#   '2. high': '61.0000',
#   '3. low': '57.8400',
#   '4. close': '60.0200',
#   '5. adjusted close': '98.9037',
#   '6. volume': '8812200',
#   '7. dividend amount': '0.0000'},
#  '2011-12-30': {'1. open': '57.0700',
#   '2. high': '59.0800',
#   '3. low': '55.2200',
#   '4. close': '57.4500',
#   '5. adjusted close': '94.6687',
#   '6. volume': '15831000',
#   '7. dividend amount': '0.3430'},
#  '2011-11-30': {'1. open': '55.7700',
#   '2. high': '58.5100',
#   '3. low': '53.1500',
#   '4. close': '57.1500',
#   '5. adjusted close': '93.6188',
#   '6. volume': '10076400',
#   '7. dividend amount': '0.0000'},
#  '2011-10-31': {'1. open': '51.4100',
#   '2. high': '59.1500',
#   '3. low': '49.1200',
#   '4. close': '57.3200',
#   '5. adjusted close': '93.8973',
#   '6. volume': '16779600',
#   '7. dividend amount': '0.0000'},
#  '2011-09-30': {'1. open': '55.8700',
#   '2. high': '56.4000',
#   '3. low': '51.1900',
#   '4. close': '51.7600',
#   '5. adjusted close': '84.7893',
#   '6. volume': '9141200',
#   '7. dividend amount': '0.2900'},
#  '2011-08-31': {'1. open': '59.8900',
#   '2. high': '59.9100',
#   '3. low': '50.4600',
#   '4. close': '55.8400',
#   '5. adjusted close': '90.9640',
#   '6. volume': '18848800',
#   '7. dividend amount': '0.0000'},
#  '2011-07-29': {'1. open': '60.3700',
#   '2. high': '62.0500',
#   '3. low': '58.7200',
#   '4. close': '59.1000',
#   '5. adjusted close': '96.2746',
#   '6. volume': '5953800',
#   '7. dividend amount': '0.0000'},
#  '2011-06-30': {'1. open': '61.5200',
#   '2. high': '61.5200',
#   '3. low': '57.7700',
#   '4. close': '60.3400',
#   '5. adjusted close': '98.2946',
#   '6. volume': '5098400',
#   '7. dividend amount': '0.2850'},
#  '2011-05-31': {'1. open': '62.7200',
#   '2. high': '62.7200',
#   '3. low': '60.0800',
#   '4. close': '61.6700',
#   '5. adjusted close': '99.9699',
#   '6. volume': '4909400',
#   '7. dividend amount': '0.0000'},
#  '2011-04-29': {'1. open': '61.0600',
#   '2. high': '62.4400',
#   '3. low': '59.2201',
#   '4. close': '62.4000',
#   '5. adjusted close': '101.1533',
#   '6. volume': '4603600',
#   '7. dividend amount': '0.0000'},
#  '2011-03-31': {'1. open': '61.1400',
#   '2. high': '61.1500',
#   '3. low': '57.3200',
#   '4. close': '60.6200',
#   '5. adjusted close': '98.2678',
#   '6. volume': '7732000',
#   '7. dividend amount': '0.2680'},
#  '2011-02-28': {'1. open': '59.2400',
#   '2. high': '61.6100',
#   '3. low': '59.1900',
#   '4. close': '60.8900',
#   '5. adjusted close': '98.2668',
#   '6. volume': '5522000',
#   '7. dividend amount': '0.0000'},
#  '2011-01-31': {'1. open': '57.9700',
#   '2. high': '59.6100',
#   '3. low': '57.7400',
#   '4. close': '58.8500',
#   '5. adjusted close': '94.9746',
#   '6. volume': '8803000',
#   '7. dividend amount': '0.0000'},
#  '2010-12-31': {'1. open': '54.9600',
#   '2. high': '57.8000',
#   '3. low': '54.9400',
#   '4. close': '57.5700',
#   '5. adjusted close': '92.9088',
#   '6. volume': '3339400',
#   '7. dividend amount': '0.2630'},
#  '2010-11-30': {'1. open': '54.4600',
#   '2. high': '56.1500',
#   '3. low': '53.7372',
#   '4. close': '54.0900',
#   '5. adjusted close': '86.8952',
#   '6. volume': '2139800',
#   '7. dividend amount': '0.0000'},
#  '2010-10-29': {'1. open': '52.5400',
#   '2. high': '54.6400',
#   '3. low': '51.7500',
#   '4. close': '54.1500',
#   '5. adjusted close': '86.9915',
#   '6. volume': '1902200',
#   '7. dividend amount': '0.0000'}}

# %%
all_dates = [i for i in stock_dates_dict.keys()]

# %%
all_dates = pd.DataFrame(all_dates)

# %%
all_dates.columns = ["Date"]

# %%
all_dates.Date = pd.to_datetime(all_dates.Date)

# %%
min(all_dates.Date)
# Out:
# Timestamp('2010-10-29 00:00:00')

# %%
max(all_dates.Date)
# Out:
# Timestamp('2022-03-09 00:00:00')

# %%
all_dates
# Out:
#           Date
# 0   2022-03-09
# 1   2022-02-28
# 2   2022-01-31
# 3   2021-12-31
# 4   2021-11-30
# ..         ...
# 133 2011-02-28
# 134 2011-01-31
# 135 2010-12-31
# 136 2010-11-30
# 137 2010-10-29
#
# [138 rows x 1 columns]

# %%
def split_years(dt):
    dt['year'] = dt['Date'].dt.year
    return [dt[dt['year'] == y] for y in dt['year'].unique()]

# %%
mins = []
maxs = []
for i in split_years(all_dates):
    mins.append(min(i.Date))
    maxs.append(max(i.Date))
    if len(i) < 12:
        print(i)
        continue
# Out:
#         Date  year
# 0 2022-03-09  2022
# 1 2022-02-28  2022
# 2 2022-01-31  2022
#           Date  year
# 135 2010-12-31  2010
# 136 2010-11-30  2010
# 137 2010-10-29  2010

# %%
mins
# Out:
# [Timestamp('2022-01-31 00:00:00'),
#  Timestamp('2021-01-29 00:00:00'),
#  Timestamp('2020-01-31 00:00:00'),
#  Timestamp('2019-01-31 00:00:00'),
#  Timestamp('2018-01-31 00:00:00'),
#  Timestamp('2017-01-31 00:00:00'),
#  Timestamp('2016-01-29 00:00:00'),
#  Timestamp('2015-01-30 00:00:00'),
#  Timestamp('2014-01-31 00:00:00'),
#  Timestamp('2013-01-31 00:00:00'),
#  Timestamp('2012-01-31 00:00:00'),
#  Timestamp('2011-01-31 00:00:00'),
#  Timestamp('2010-10-29 00:00:00')]

# %%
maxs
# Out:
# [Timestamp('2022-03-09 00:00:00'),
#  Timestamp('2021-12-31 00:00:00'),
#  Timestamp('2020-12-31 00:00:00'),
#  Timestamp('2019-12-31 00:00:00'),
#  Timestamp('2018-12-31 00:00:00'),
#  Timestamp('2017-12-29 00:00:00'),
#  Timestamp('2016-12-30 00:00:00'),
#  Timestamp('2015-12-31 00:00:00'),
#  Timestamp('2014-12-31 00:00:00'),
#  Timestamp('2013-12-31 00:00:00'),
#  Timestamp('2012-12-31 00:00:00'),
#  Timestamp('2011-12-30 00:00:00'),
#  Timestamp('2010-12-31 00:00:00')]

# %% [markdown]
# gets keys from dict, separtes keys by year gets min and max per year and compares the opening price for stock for returns

# %%
maxs = list(map(lambda x: x.strftime("%Y-%m-%d"), maxs))
mins = list(map(lambda x: x.strftime("%Y-%m-%d"), mins))

# %%
# for key in stock_dates_dict:
#     print(key, stock_dates_dict[key])

# %%
# https://www.investopedia.com/terms/y/yearly-rate-of-return-method.asp
def yearly_return(first, last):
    first =  float(first)
    last = float(last)
    return (last - first ) / first*100

# %%
mins
# Out:
# ['2022-01-31',
#  '2021-01-29',
#  '2020-01-31',
#  '2019-01-31',
#  '2018-01-31',
#  '2017-01-31',
#  '2016-01-29',
#  '2015-01-30',
#  '2014-01-31',
#  '2013-01-31',
#  '2012-01-31',
#  '2011-01-31',
#  '2010-10-29']

# %%
maxs
# Out:
# ['2022-03-09',
#  '2021-12-31',
#  '2020-12-31',
#  '2019-12-31',
#  '2018-12-31',
#  '2017-12-29',
#  '2016-12-30',
#  '2015-12-31',
#  '2014-12-31',
#  '2013-12-31',
#  '2012-12-31',
#  '2011-12-30',
#  '2010-12-31']

# %%
for i in maxs:
    print('maxs ', i, stock_dates_dict[i]["4. close"])
# Out:
# maxs  2022-03-09 392.9000
# maxs  2021-12-31 436.5700
# maxs  2020-12-31 343.6900
# maxs  2019-12-31 295.8000
# maxs  2018-12-31 229.8100
# maxs  2017-12-29 245.2900
# maxs  2016-12-30 205.3100
# maxs  2015-12-31 186.9300
# maxs  2014-12-31 188.4000
# maxs  2013-12-31 169.1500
# maxs  2012-12-31 65.1900
# maxs  2011-12-30 57.4500
# maxs  2010-12-31 57.5700

# %%
for i in mins:
    print('mins ', i , stock_dates_dict[i]["1. open"])
# Out:
# mins  2022-01-31 437.9300
# mins  2021-01-29 345.0200
# mins  2020-01-31 297.2900
# mins  2019-01-31 226.1800
# mins  2018-01-31 246.1500
# mins  2017-01-31 206.6800
# mins  2016-01-29 183.7700
# mins  2015-01-30 189.2900
# mins  2014-01-31 168.5300
# mins  2013-01-31 66.4700
# mins  2012-01-31 58.4500
# mins  2011-01-31 57.9700
# mins  2010-10-29 52.5400

# %%
rates_of_return = yearly_return(stock_dates_dict[mins[0]]["1. open"], stock_dates_dict[maxs[0]]["4. close"])
rates_of_return
# Out:
# -10.28246523416985

# %%
yroi = []
for i in range(len(maxs)):
    if len(maxs)!=len(mins):
        print("Different")
    yroi.append(yearly_return(stock_dates_dict[mins[i]]["1. open"], stock_dates_dict[maxs[i]]["4. close"]))
yroi
# Out:
# [-10.28246523416985,
#  26.534693640948355,
#  15.607655824279314,
#  30.780794057830047,
#  -6.638228722323787,
#  18.68105283530094,
#  11.721173205637477,
#  -1.2467642242062367,
#  11.790185723610042,
#  154.4757033248082,
#  11.531223267750205,
#  -0.8970156977747041,
#  9.573658165207464]

# %%
np.median(yroi)
# Out:
# 11.721173205637477

# %%
np.std(yroi)
# Out:
# 40.27250395170562
